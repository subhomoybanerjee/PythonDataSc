# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %%
np.random.seed(10)
df=pd.DataFrame(randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])
df
# Out:
#           W         X         Y         Z
# A  1.331587  0.715279 -1.545400 -0.008384
# B  0.621336 -0.720086  0.265512  0.108549
# C  0.004291 -0.174600  0.433026  1.203037
# D -0.965066  1.028274  0.228630  0.445138
# E -1.136602  0.135137  1.484537 -1.079805

# %%
df[['W','Z']]
# Out:
#           W         Z
# A  1.331587 -0.008384
# B  0.621336  0.108549
# C  0.004291  1.203037
# D -0.965066  0.445138
# E -1.136602 -1.079805

# %%
df['new']=df['W']+5
df
# Out:
#           W         X         Y         Z       new
# A  1.331587  0.715279 -1.545400 -0.008384  6.331587
# B  0.621336 -0.720086  0.265512  0.108549  5.621336
# C  0.004291 -0.174600  0.433026  1.203037  5.004291
# D -0.965066  1.028274  0.228630  0.445138  4.034934
# E -1.136602  0.135137  1.484537 -1.079805  3.863398

# %%
df.drop('A')
# Out:
#           W         X         Y         Z       new
# B  0.621336 -0.720086  0.265512  0.108549  5.621336
# C  0.004291 -0.174600  0.433026  1.203037  5.004291
# D -0.965066  1.028274  0.228630  0.445138  4.034934
# E -1.136602  0.135137  1.484537 -1.079805  3.863398

# %%
df.drop('Z',axis=1)
# Out:
#           W         X         Y       new
# A  1.331587  0.715279 -1.545400  6.331587
# B  0.621336 -0.720086  0.265512  5.621336
# C  0.004291 -0.174600  0.433026  5.004291
# D -0.965066  1.028274  0.228630  4.034934
# E -1.136602  0.135137  1.484537  3.863398

# %%
df.loc['A']
# Out:
# W      1.331587
# X      0.715279
# Y     -1.545400
# Z     -0.008384
# new    6.331587
# Name: A, dtype: float64

# %%
df.iloc[0]
# Out:
# W      1.331587
# X      0.715279
# Y     -1.545400
# Z     -0.008384
# new    6.331587
# Name: A, dtype: float64

# %%
df.iloc[0:2,0:2]
# Out:
#           W         X
# A  1.331587  0.715279
# B  0.621336 -0.720086

# %%
df.iloc[2,2]
# Out:
# 0.433026189953598

# %%
df.loc[['A','B'],['W','X']]
# Out:
#           W         X
# A  1.331587  0.715279
# B  0.621336 -0.720086

# %%
df[df>0]
# Out:
#           W         X         Y         Z       new
# A  1.331587  0.715279       NaN       NaN  6.331587
# B  0.621336       NaN  0.265512  0.108549  5.621336
# C  0.004291       NaN  0.433026  1.203037  5.004291
# D       NaN  1.028274  0.228630  0.445138  4.034934
# E       NaN  0.135137  1.484537       NaN  3.863398

# %%
df['W']<0
# Out:
# A    False
# B    False
# C    False
# D     True
# E     True
# Name: W, dtype: bool

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z       new
# A  1.331587  0.715279 -1.545400 -0.008384  6.331587
# B  0.621336 -0.720086  0.265512  0.108549  5.621336
# C  0.004291 -0.174600  0.433026  1.203037  5.004291

# %%
df.reset_index()
# Out:
#   index         W         X         Y         Z       new
# 0     A  1.331587  0.715279 -1.545400 -0.008384  6.331587
# 1     B  0.621336 -0.720086  0.265512  0.108549  5.621336
# 2     C  0.004291 -0.174600  0.433026  1.203037  5.004291
# 3     D -0.965066  1.028274  0.228630  0.445138  4.034934
# 4     E -1.136602  0.135137  1.484537 -1.079805  3.863398

# %%
df
# Out:
#           W         X         Y         Z       new
# A  1.331587  0.715279 -1.545400 -0.008384  6.331587
# B  0.621336 -0.720086  0.265512  0.108549  5.621336
# C  0.004291 -0.174600  0.433026  1.203037  5.004291
# D -0.965066  1.028274  0.228630  0.445138  4.034934
# E -1.136602  0.135137  1.484537 -1.079805  3.863398

# %%
#df.drop(['new'],axis=1,inplace=True)

# %%
newind='CA NY WY OR CO'.split()
newind
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
df['States']=newind
df
# Out:
#           W         X         Y         Z States
# A  1.331587  0.715279 -1.545400 -0.008384     CA
# B  0.621336 -0.720086  0.265512  0.108549     NY
# C  0.004291 -0.174600  0.433026  1.203037     WY
# D -0.965066  1.028274  0.228630  0.445138     OR
# E -1.136602  0.135137  1.484537 -1.079805     CO

# %%
df.set_index('States',inplace=True)

# %%
df
# Out:
#                W         X         Y         Z
# States
# CA      1.331587  0.715279 -1.545400 -0.008384
# NY      0.621336 -0.720086  0.265512  0.108549
# WY      0.004291 -0.174600  0.433026  1.203037
# OR     -0.965066  1.028274  0.228630  0.445138
# CO     -1.136602  0.135137  1.484537 -1.079805

# %%
outside=['G1' for i in range(3)] +['G2' for i in range(3)]
inside=[i%4 for i in range(1,8) if i%4!=0 ]
hier_index=list(zip(outside,inside))
hier_index=pd.MultiIndex.from_tuples(hier_index)
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
hier_index
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
df2=pd.DataFrame(randn(6,2),hier_index,['A','B'])
df2
# Out:
#                 A         B
# (G1, 1)  0.132708 -0.476142
# (G1, 2)  1.308473  0.195013
# (G1, 3)  0.400210 -0.337632
# (G2, 1)  1.256472 -0.731970
# (G2, 2)  0.660232 -0.350872
# (G2, 3) -0.939433 -0.489337

# %%
df2.index.names=['Groups']
df2
# Out:
#                 A         B
# Groups
# (G1, 1)  0.132708 -0.476142
# (G1, 2)  1.308473  0.195013
# (G1, 3)  0.400210 -0.337632
# (G2, 1)  1.256472 -0.731970
# (G2, 2)  0.660232 -0.350872
# (G2, 3) -0.939433 -0.489337

# %%
df2.xs(('G1',1))
# Out:
# A    0.132708
# B   -0.476142
# Name: (G1, 1), dtype: float64

# %%
d={'A':[1,2,np.nan],
      'B':[5,np.nan,np.nan],
      'C':[1,2,3]}
df3=pd.DataFrame(d)
df3.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df3.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df3.fillna(value='bhar de')
# Out:
#          A        B  C
# 0      1.0      5.0  1
# 1      2.0  bhar de  2
# 2  bhar de  bhar de  3

# %%
df3['A'].fillna(df3['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
data={'company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
            'person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
            'sales':[200,120,340,124,243,350]}
df4=pd.DataFrame(data)

# %%
df4.groupby('company').count()
# Out:
#          person  sales
# company
# FB            2      2
# GOOG          2      2
# MSFT          2      2

# %%
df4.groupby('company').max()
# Out:
#           person  sales
# company
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
df4.groupby('company').sum()
# Out:
#          sales
# company
# FB         593
# GOOG       320
# MSFT       464

# %%
df4.groupby('company').describe()
# Out:
#         sales
#         count   mean         std    min     25%    50%     75%    max
# company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
pd.merge(left,right,how='inner',on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col2'].unique()
# Out:
# array([444, 555, 666])

# %%
df['col2'].value_counts()
# Out:
# 444    2
# 555    1
# 666    1
# Name: col2, dtype: int64

# %%
df[(df['col1']>2) & (df['col2']==666) ]
# Out:
#    col1  col2 col3
# 2     3   666  ghi

# %%
df['col1']>2
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: col1, dtype: bool

# %%
def power2(x):
    return x**2

# %%
df['col1'].apply(power2)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col1, dtype: int64

# %%
df['col3'].apply(lambda x:len(x))
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.sort_values('col2')
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %%
df.isnull()
# Out:
#     col1   col2   col3
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False

# %%
data =   {'A':['foo','foo','foo','bar','bar','bar'],
                'B':['one','one','two','two','one','one'],
                'C':['x','y','x','y','x','y'],
                'D':[1,3,2,5,4,1]}

# %%
df=pd.DataFrame(data)
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df.pivot_table(values='D',index=['A','B'],columns=['C'])
# Out:
# C          x    y
# A   B
# bar one  4.0  1.0
#     two  NaN  5.0
# foo one  1.0  3.0
#     two  2.0  NaN

# %%
import sqlalchemy
import lxml
import html5lib
from bs4 import BeautifulSoup
# !pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df=pd.read_csv('example.csv')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('My_output',index=False)
pd.read_csv('My_output')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
pd.read_excel('Excel_Sample.xlsx',sheet_name='Sheet1',index_col=0)
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_excel('Excel_Sample2.xlsx',sheet_name='NewSheet')

# %%
data = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')

# %%
data[0]
# Out:
#                          Bank NameBank           CityCity StateSt  CertCert  \
# 0                    Almena State Bank             Almena      KS     15426
# 1           First City Bank of Florida  Fort Walton Beach      FL     16748
# 2                 The First State Bank      Barboursville      WV     14361
# 3                   Ericson State Bank            Ericson      NE     18265
# 4     City National Bank of New Jersey             Newark      NJ     21111
# ..                                 ...                ...     ...       ...
# 558                 Superior Bank, FSB           Hinsdale      IL     32646
# 559                Malta National Bank              Malta      OH      6629
# 560    First Alliance Bank & Trust Co.         Manchester      NH     34264
# 561  National State Bank of Metropolis         Metropolis      IL      3815
# 562                   Bank of Honolulu           Honolulu      HI     21029
#
# ...

# %%
from sqlalchemy import create_engine

# %%
engine=create_engine('sqlite:///:memory:')

# %%
df.to_sql('my_table',engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-327-a3f7df557fed> in <module>
# ----> 1 df.to_sql('my_table',engine)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# ...

# %%
sqldf=pd.read_sql('my_table',con=engine)

# %%
sqldf
# Out:
#    index   a   b   c   d
# 0      0   0   1   2   3
# 1      1   4   5   6   7
# 2      2   8   9  10  11
# 3      3  12  13  14  15

# %%
df=pd.read_csv('Salaries.csv')

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
df['BasePay'].mean()
# Out:
# 66325.4488404877

# %%
df['OvertimePay'].max()
# Out:
# 245131.88

# %%
a='EmployeeName'
b='JobTitle'
name='JOSEPH DRISCOLL'
df[df[a]==name][b]
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
pay='TotalPayBenefits'
df[df[a]==name][pay]
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
df[df[pay]==df[pay].max()][a]
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %%
df[df[pay]==df[pay].min()][a]
# Out:
# 148653    Joe Lopez
# Name: EmployeeName, dtype: object

# %%
df.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
df['JobTitle'].nunique()
# Out:
# 2159

# %%
df['JobTitle'].value_counts().head(6)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Custodian                       2418
# Name: JobTitle, dtype: int64

# %%
sum(df[df['Year']==2013]['JobTitle'].value_counts()==1)
# Out:
# 202

# %%
def chief_string(title):
    if 'chief' in title.lower():
        return True
    else:
        return False

sum(df['JobTitle'].apply(lambda x: chief_string(x)))
# Out:
# 627

# %%
sum(df['JobTitle'].apply(lambda x:'chief' in x.lower()))
# Out:
# 627

# %%
df['lenJ']=df['JobTitle'].apply(lambda x:len(x))
df[['TotalPayBenefits','lenJ']].corr()
# Out:
#                   TotalPayBenefits      lenJ
# TotalPayBenefits          1.000000 -0.036878
# lenJ                     -0.036878  1.000000

# %%
df=pd.read_csv('Ecommerce Purchases.csv')
df.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
df['Purchase Price'].min()
# Out:
# 0.0

# %%
df[df['Language']=='en'].count()
# Out:
# Address             1098
# Lot                 1098
# AM or PM            1098
# Browser Info        1098
# Company             1098
# Credit Card         1098
# CC Exp Date         1098
# CC Security Code    1098
# CC Provider         1098
# Email               1098
# Job                 1098
# IP Address          1098
# Language            1098
# Purchase Price      1098
# dtype: int64

# %%
sum(df['Job'].apply(lambda x:'Lawyer' in x))
# Out:
# 30

# %%
df['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
df['Job'].value_counts().head()
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: Job, dtype: int64

# %%
df[df['Lot']=='90 WT']['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %%
df[df['Credit Card']==4926535242672853]['Email']
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %%
df[(df['CC Provider']=='American Express') & (df['Purchase Price']>95)].count()
# Out:
# Address             39
# Lot                 39
# AM or PM            39
# Browser Info        39
# Company             39
# Credit Card         39
# CC Exp Date         39
# CC Security Code    39
# CC Provider         39
# Email               39
# Job                 39
# IP Address          39
# Language            39
# Purchase Price      39
# dtype: int64

# %%
sum(df['CC Exp Date'].apply(lambda x:x.split('/')[1]=='25'))
# Out:
# 1033

# %%
df['Email'].apply(lambda x:x.split('@')[1]).value_counts().head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
df1=pd.read_csv('df1.csv',index_col=0)
df2=pd.read_csv('df2.csv')
df3=pd.read_csv('df3.csv')
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df1['A'].hist(bins=30)

# %%
df1['A'].plot(kind='hist',bins=30)

# %%
df1['A'].plot.hist(bins=30)

# %%
df2.plot.area()

# %%
df2.plot.bar(stacked=True)

# %%
df1.plot.line(y='B',figsize=(15,3))

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*10)

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')

# %%
df2.plot.box()

# %%
df=pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])
df
# Out:
#             a         b
# 0   -0.770403 -0.839034
# 1    0.126265 -0.174433
# 2    1.030765  1.353904
# 3    1.058533  0.202388
# 4   -0.764262 -0.550043
# ..        ...       ...
# 995  0.845935 -0.343001
# 996  0.199829 -1.576113
# 997 -1.987112 -0.173144
# 998 -0.868046 -1.315122
# 999 -0.004236  0.567647
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,figsize=(7,5))

# %%
df['a'].plot.kde()

# %%
df['a'].plot.density()

# %%
df3
# Out:
#             a         b         c         d
# 0    0.336272  0.325011  0.001020  0.401402
# 1    0.980265  0.831835  0.772288  0.076485
# 2    0.480387  0.686839  0.000575  0.746758
# 3    0.502106  0.305142  0.768608  0.654685
# 4    0.856602  0.171448  0.157971  0.321231
# ..        ...       ...       ...       ...
# 495  0.528705  0.226122  0.055835  0.131962
# 496  0.324730  0.215201  0.935302  0.794115
# 497  0.118036  0.264574  0.629206  0.824062
# 498  0.227021  0.660209  0.851353  0.478676
# 499  0.466157  0.753000  0.115391  0.279712
#
# [500 rows x 4 columns]

# %%
df3.plot.scatter(x='a',y='b',c='red',s=50,figsize=(10,3))

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
df3['a'].plot.hist(bins=25,edgecolor ="white",alpha=0.5)

# %%
df3[['a','b']].plot.box()

# %%
df3['d'].plot.kde()

# %%
df3['d'].plot.kde(ls='dotted',lw=5)

# %%
df3.iloc[0:31,].plot.area(alpha=0.4)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.15))
